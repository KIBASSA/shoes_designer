# %%
import os
import sys
sys.path.append("../src")
sys.path.append("../src/pix2pixs")
import glob
from pix2pix import train

# %%
train("pix2pix_black_briant_high_resolution", "../data/high resolution_style_black_brilliant_pair")
# Out:
# save_model : True
# 2651
#   0%|          | 0/530 [00:00<?, ?it/s]
# Pretrained initial state
# Epoch 0: Step 200: Generator (U-Net) loss: 3.0539990913867947, Discriminator loss: 0.6756230407953264
# Epoch 0: Step 400: Generator (U-Net) loss: 3.015187633037569, Discriminator loss: 0.6762702506780628
#   0%|          | 0/530 [00:00<?, ?it/s]
# Epoch 1: Step 600: Generator (U-Net) loss: 3.067672232389451, Discriminator loss: 0.6818699443340301
# Epoch 1: Step 800: Generator (U-Net) loss: 2.995692406892778, Discriminator loss: 0.6818287619948388

# %%
pip install ipywidgets
